# %% [markdown]
# <a href="https://colab.research.google.com/github/younghoonNa/PythonDT2/blob/main/Day1_%EB%A9%80%ED%8B%B0%EC%BA%A0%ED%8D%BC%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('python')
# Out:
# python

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.sample(10)
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 484         1       1    male  25.0  ...     B    Cherbourg    yes  False
# 42          0       3    male   NaN  ...   NaN    Cherbourg     no   True
# 219         0       2    male  30.0  ...   NaN  Southampton     no   True
# 696         0       3    male  44.0  ...   NaN  Southampton     no   True
# 749         0       3    male  31.0  ...   NaN   Queenstown     no   True
# 463         0       2    male  48.0  ...   NaN  Southampton     no   True
# 368         1       3  female   NaN  ...   NaN   Queenstown    yes   True
# 585         1       1  female  18.0  ...     E  Southampton    yes  False
# 640         0       3    male  20.0  ...   NaN  Southampton     no   True
# 546         1       2  female  19.0  ...   NaN  Southampton    yes  False
#
# [10 rows x 15 columns]

# %%
df.sample(frac=0.2)
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 404         0       3  female  20.0  ...   NaN  Southampton     no   True
# 341         1       1  female  24.0  ...     C  Southampton    yes  False
# 379         0       3    male  19.0  ...   NaN  Southampton     no   True
# 592         0       3    male  47.0  ...   NaN  Southampton     no   True
# 762         1       3    male  20.0  ...   NaN    Cherbourg    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 261         1       3    male   3.0  ...   NaN  Southampton    yes  False
# 18          0       3  female  31.0  ...   NaN  Southampton     no  False
# 460         1       1    male  48.0  ...     E  Southampton    yes   True
# 97          1       1    male  23.0  ...     D    Cherbourg    yes  False
# 588         0       3    male  22.0  ...   NaN  Southampton     no   True
#
# [178 rows x 15 columns]

# %%
np.random.choice(890, 10)
# Out:
# array([561, 140,   4, 444, 540, 329,  42, 574, 670, 786])

# %%
df.values[np.random.choice(890, 10)][0]
# Out:
# array([1, 2, 'male', nan, 0, 0, 13.8625, 'C', 'Second', 'man', True, nan,
#        'Cherbourg', 'yes', True], dtype=object)

# %%
df[ : : 5]
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 5           0       3    male   NaN  ...   NaN   Queenstown     no   True
# 10          1       3  female   4.0  ...     G  Southampton    yes  False
# 15          1       2  female  55.0  ...   NaN  Southampton    yes   True
# 20          0       2    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 870         0       3    male  26.0  ...   NaN  Southampton     no   True
# 875         1       3  female  15.0  ...   NaN    Cherbourg    yes   True
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [179 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split

Y = df.survived
X = df.age

x_train, x_test = train_test_split(X)

# %%
x_train.shape, x_test.shape
# Out:
# ((668,), (223,))

# %%
x_train.index, x_test.index
# Out:
# (Int64Index([222, 879, 819,   1, 563, 890,  15, 114, 347, 252,
#              ...
#              493, 738, 639, 303, 525, 660,  30, 534, 370, 638],
#             dtype='int64', length=668),
#  Int64Index([773, 509, 159, 877,  53, 176, 131, 428, 881, 831,
#              ...
#              247, 474, 746, 378, 425, 803, 526, 719, 354, 679],
#             dtype='int64', length=223))

# %%
x_train, x_test = train_test_split(X, random_state=0)

# %%
x_train.index, x_test.index
# Out:
# (Int64Index([105,  68, 253, 320, 706, 271, 424, 752, 615,   2,
#              ...
#              723,   9, 359, 707, 763, 835, 192, 629, 559, 684],
#             dtype='int64', length=668),
#  Int64Index([495, 648, 278,  31, 255, 298, 609, 318, 484, 367,
#              ...
#              852, 239, 646, 122, 788, 167, 306, 379, 742,  10],
#             dtype='int64', length=223))

# %%
y_train, y_test = train_test_split(Y, random_state=0)

# %%
y_train.index, y_test.index
# Out:
# (Int64Index([105,  68, 253, 320, 706, 271, 424, 752, 615,   2,
#              ...
#              723,   9, 359, 707, 763, 835, 192, 629, 559, 684],
#             dtype='int64', length=668),
#  Int64Index([495, 648, 278,  31, 255, 298, 609, 318, 484, 367,
#              ...
#              852, 239, 646, 122, 788, 167, 306, 379, 742,  10],
#             dtype='int64', length=223))

# %%
Y.shape
# Out:
# (891,)

# %%
X.shape
# Out:
# (891,)

# %%
x_train, x_test = train_test_split(X, test_size=0.5)
x_train.shape, x_test.shape
# Out:
# ((445,), (446,))

# %%
X = df.loc[:, df.columns != 'survived']
X
# Out:
#      pclass     sex   age  sibsp  ...  deck  embark_town alive  alone
# 0         3    male  22.0      1  ...   NaN  Southampton    no  False
# 1         1  female  38.0      1  ...     C    Cherbourg   yes  False
# 2         3  female  26.0      0  ...   NaN  Southampton   yes   True
# 3         1  female  35.0      1  ...     C  Southampton   yes  False
# 4         3    male  35.0      0  ...   NaN  Southampton    no   True
# ..      ...     ...   ...    ...  ...   ...          ...   ...    ...
# 886       2    male  27.0      0  ...   NaN  Southampton    no   True
# 887       1  female  19.0      0  ...     B  Southampton   yes   True
# 888       3  female   NaN      1  ...   NaN  Southampton    no  False
# 889       1    male  26.0      0  ...     C    Cherbourg   yes   True
# 890       3    male  32.0      0  ...   NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
X = df.loc[:, df.columns != 'survived']
Y = df.survived

x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=2)
display(Y.value_counts(normalize=True))
display(y_train.value_counts(normalize=True))
display(y_test.value_counts(normalize=True))
# Out:
# 0    0.616162
# 1    0.383838
# Name: survived, dtype: float64
# 0    0.625749
# 1    0.374251
# Name: survived, dtype: float64
# 0    0.587444
# 1    0.412556
# Name: survived, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=2, stratify=Y)
display(Y.value_counts(normalize=True))
display(y_train.value_counts(normalize=True))
display(y_test.value_counts(normalize=True))
# Out:
# 0    0.616162
# 1    0.383838
# Name: survived, dtype: float64
# 0    0.616766
# 1    0.383234
# Name: survived, dtype: float64
# 0    0.61435
# 1    0.38565
# Name: survived, dtype: float64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %%
df.age.hist(bins=20)

# %%
from sklearn.datasets import load_iris

iris =load_iris()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

X = iris.data
Y = iris.target

x_train, x_test, y_train, y_test = train_test_split(X,Y, random_state= 0)

model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                  5.1               3.5  ...               0.2        0
# 1                  4.9               3.0  ...               0.2        0
# 2                  4.7               3.2  ...               0.2        0
# 3                  4.6               3.1  ...               0.2        0
# 4                  5.0               3.6  ...               0.2        0
# ..                 ...               ...  ...               ...      ...
# 145                6.7               3.0  ...               2.3        2
# 146                6.3               2.5  ...               1.9        2
# 147                6.5               3.0  ...               2.0        2
# 148                6.2               3.4  ...               2.3        2
# 149                5.9               3.0  ...               1.8        2
#
# [150 rows x 5 columns]

# %%
pred = model.predict(x_test)
pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2])

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1])

# %%
model.score(x_test, y_test)
# Out:
# 0.9736842105263158

# %%
model.predict([[4.1, 2.3, 3.3, 0.5]])
# Out:
# array([1])

# %%
ks = np.arange(1, 11)

train_score = []
test_score = []

for k in ks:
  model = KNeighborsClassifier(n_neighbors=k)
  model.fit(x_train, y_train)
  train_score.append(model.score(x_train, y_train))
  test_score.append(model.score(x_test, y_test))

# %%
train_score
# Out:
# [1.0,
#  0.9642857142857143,
#  0.9642857142857143,
#  0.9732142857142857,
#  0.9732142857142857,
#  0.9642857142857143,
#  0.9732142857142857,
#  0.9732142857142857,
#  0.9642857142857143,
#  0.9732142857142857]

# %%
test_score
# Out:
# [0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158,
#  0.9736842105263158]

# %%
plt.plot(ks, train_score, 'b^-', label='train')
plt.plot(ks, test_score, 'ro--', label='test')
plt.legend()
plt.grid()
